# %%
import pandas as pd

# %%
df = pd.read_csv("../../data/salmon_data/all_chromosomes.csv", index_col=0)
pivoted_df = df.pivot_table(index='sample.id', columns='gene', values=["gene.expression"],  aggfunc='mean')

X = pivoted_df
X.columns = X.columns.droplevel(0)
pivoted_df = df.pivot_table(index='sample.id', values=["gutted.weight.kg"],  aggfunc='mean')
y = pivoted_df

# %%
metadata = pd.read_csv("../../data/salmon_data/HoloFish_FishVariables_20221116.csv", index_col=0)

# metadata.columns = metadata.columns.droplevel(0)
metadata
# Out:
#           Size.class  Gutted.Weight.kg  Tapeworm.index  Tapeworm.present  \
# Sample.ID
# F001          Medium             3.240               1              True
# F010           Small             1.770               1              True
# F100          Medium             3.150               1              True
# F101          Medium             3.210               1              True
# F102          Medium             3.340               1              True
# ...              ...               ...             ...               ...
# F416           Large             5.840               2              True
# F417           Small             2.310               2              True
# F418           Small             2.360               0             False
# F419          Medium             2.910               2              True
# F420           Small             1.695               2              True
#
#           Feed.Type Metabolome.batch HostG.Ind.ID  Dataset.MetaG  \
# Sample.ID
# ...

# %%
tapeworm_df = metadata[["Tapeworm.index"]]
tapeworm_df
# Out:
#            Tapeworm.index
# Sample.ID
# F001                    1
# F010                    1
# F100                    1
# F101                    1
# F102                    1
# ...                   ...
# F416                    2
# F417                    2
# F418                    0
# F419                    2
# F420                    2
#
# [463 rows x 1 columns]

# %%
XY = pd.merge(left=X, right=tapeworm_df, left_on=X.index, right_on=tapeworm_df.index)
XY
# Out:
#     key_0      1433b      143b2     143g1      2a5e        4f2     5nt1a  \
# 0    F001   8.298729  10.908738  9.425202  8.779539  10.929669  7.111388
# 1    F002   8.228803  10.642114  8.008146  8.664696   9.849611  7.783078
# 2    F003   8.643025  10.539054  8.000962  8.201590  10.582260  7.636555
# 3    F004   5.956833  10.835880  8.092081  8.547840   9.075364  8.207422
# 4    F005   6.892844  11.015085  7.600201  8.461058   9.100262  7.466592
# ..    ...        ...        ...       ...       ...        ...       ...
# 297  F450   8.197073  10.629662  9.355759  8.723406  10.701376  7.170370
# 298  F456   7.759628  11.055183  8.654288  9.059819   9.624544  7.364918
# 299  F458   9.983777  11.766481  8.220540  8.019322  10.493871  7.168827
# 300  F459   8.409117  10.899049  9.156758  8.108310   9.991265  7.827205
# 301  F461  10.594237  11.204688  5.033837  8.015974   8.028348  8.265764
#
#      LOC100136352  LOC100136353  LOC100136354  ...      znt4      znt6  \
# ...

# %%
XY.rename(columns={"key_0": "Sample.ID"}, inplace=True)
XY.index = XY["Sample.ID"]
XY
# Out:
#           Sample.ID      1433b      143b2     143g1      2a5e        4f2  \
# Sample.ID
# F001           F001   8.298729  10.908738  9.425202  8.779539  10.929669
# F002           F002   8.228803  10.642114  8.008146  8.664696   9.849611
# F003           F003   8.643025  10.539054  8.000962  8.201590  10.582260
# F004           F004   5.956833  10.835880  8.092081  8.547840   9.075364
# F005           F005   6.892844  11.015085  7.600201  8.461058   9.100262
# ...             ...        ...        ...       ...       ...        ...
# F450           F450   8.197073  10.629662  9.355759  8.723406  10.701376
# F456           F456   7.759628  11.055183  8.654288  9.059819   9.624544
# F458           F458   9.983777  11.766481  8.220540  8.019322  10.493871
# F459           F459   8.409117  10.899049  9.156758  8.108310   9.991265
# F461           F461  10.594237  11.204688  5.033837  8.015974   8.028348
#
#               5nt1a  LOC100136352  LOC100136353  LOC100136354  ...      znt4  \
# ...

# %%
XY.drop("Sample.ID", axis=1,inplace=True)
XY
# Out:
#                1433b      143b2     143g1      2a5e        4f2     5nt1a  \
# Sample.ID
# F001        8.298729  10.908738  9.425202  8.779539  10.929669  7.111388
# F002        8.228803  10.642114  8.008146  8.664696   9.849611  7.783078
# F003        8.643025  10.539054  8.000962  8.201590  10.582260  7.636555
# F004        5.956833  10.835880  8.092081  8.547840   9.075364  8.207422
# F005        6.892844  11.015085  7.600201  8.461058   9.100262  7.466592
# ...              ...        ...       ...       ...        ...       ...
# F450        8.197073  10.629662  9.355759  8.723406  10.701376  7.170370
# F456        7.759628  11.055183  8.654288  9.059819   9.624544  7.364918
# F458        9.983777  11.766481  8.220540  8.019322  10.493871  7.168827
# F459        8.409117  10.899049  9.156758  8.108310   9.991265  7.827205
# F461       10.594237  11.204688  5.033837  8.015974   8.028348  8.265764
#
#            LOC100136352  LOC100136353  LOC100136354  LOC100136364  ...  \
# ...

# %%
# XY.columns = XY.columns.droplevel(0)
XY.columns
# Out:
# Index(['1433b', '143b2', '143g1', '2a5e', '4f2', '5nt1a', 'LOC100136352',
#        'LOC100136353', 'LOC100136354', 'LOC100136364',
#        ...
#        'znt4', 'znt6', 'zranb2', 'zswim5', 'zswim8', 'zte38', 'zufsp', 'zyg11',
#        'zzef1', 'Tapeworm.index'],
#       dtype='object', length=19410)

# %%
len(df["gene"].unique())
# Out:
# 19409

# %%
X.index
# Out:
# Index(['F001', 'F002', 'F003', 'F004', 'F005', 'F006', 'F008', 'F011', 'F012',
#        'F013',
#        ...
#        'F443', 'F445', 'F446', 'F447', 'F448', 'F450', 'F456', 'F458', 'F459',
#        'F461'],
#       dtype='object', name='sample.id', length=302)

# %%
XY_reformatted = pd.DataFrame(data= XY.values, columns=list(XY.columns), index = list(XY.index))
XY_reformatted
# Out:
#           1433b      143b2     143g1      2a5e        4f2     5nt1a  \
# F001   8.298729  10.908738  9.425202  8.779539  10.929669  7.111388
# F002   8.228803  10.642114  8.008146  8.664696   9.849611  7.783078
# F003   8.643025  10.539054  8.000962  8.201590  10.582260  7.636555
# F004   5.956833  10.835880  8.092081  8.547840   9.075364  8.207422
# F005   6.892844  11.015085  7.600201  8.461058   9.100262  7.466592
# ...         ...        ...       ...       ...        ...       ...
# F450   8.197073  10.629662  9.355759  8.723406  10.701376  7.170370
# F456   7.759628  11.055183  8.654288  9.059819   9.624544  7.364918
# F458   9.983777  11.766481  8.220540  8.019322  10.493871  7.168827
# F459   8.409117  10.899049  9.156758  8.108310   9.991265  7.827205
# F461  10.594237  11.204688  5.033837  8.015974   8.028348  8.265764
#
#       LOC100136352  LOC100136353  LOC100136354  LOC100136364  ...      znt4  \
# ...

# %%
# XY = pd.merge(left=XY_reformatted, right=y, left_on=X_reformatted.index, right_on=y.index)
# XY.index = list(XY["key_0"])
# XY.drop("key_0", axis=1, inplace=True)

# %%
XY_reformatted
# Out:
#           1433b      143b2     143g1      2a5e        4f2     5nt1a  \
# F001   8.298729  10.908738  9.425202  8.779539  10.929669  7.111388
# F002   8.228803  10.642114  8.008146  8.664696   9.849611  7.783078
# F003   8.643025  10.539054  8.000962  8.201590  10.582260  7.636555
# F004   5.956833  10.835880  8.092081  8.547840   9.075364  8.207422
# F005   6.892844  11.015085  7.600201  8.461058   9.100262  7.466592
# ...         ...        ...       ...       ...        ...       ...
# F450   8.197073  10.629662  9.355759  8.723406  10.701376  7.170370
# F456   7.759628  11.055183  8.654288  9.059819   9.624544  7.364918
# F458   9.983777  11.766481  8.220540  8.019322  10.493871  7.168827
# F459   8.409117  10.899049  9.156758  8.108310   9.991265  7.827205
# F461  10.594237  11.204688  5.033837  8.015974   8.028348  8.265764
#
#       LOC100136352  LOC100136353  LOC100136354  LOC100136364  ...      znt4  \
# ...

# %%
XY_reformatted.to_csv("../../data/salmon_data/transcriptome_tapeworm_XY.csv")
